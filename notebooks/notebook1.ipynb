# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\DELL\Desktop\PROJECTS\Netflix-Movie-Recommendation\data\raw data\netflix_titles.csv")

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %% [markdown]
# The dataset contains missing values in several columns and a mix of categorical and numerical data.

# %%
df.describe().round()
# Out:
#        release_year
# count        8807.0
# mean         2014.0
# std             9.0
# min          1925.0
# 25%          2013.0
# 50%          2017.0
# 75%          2019.0
# max          2021.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate records were found in the data

# %%
df.to_csv(
    r"C:\Users\DELL\Desktop\PROJECTS\Netflix-Movie-Recommendation\data\clean data\netflix_titles_clean.csv",
    index=False
)

# %%
import os

os.path.exists(r"C:\Users\DELL\Desktop\PROJECTS\Netflix-Movie-Recommendation\data\clean data\netflix_titles_clean.csv")
# Out:
# True

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Several columns contain missing values

# %%
df.drop(columns=['show_id', 'date_added', 'duration'], inplace=True)

# %% [markdown]
# Unnecessary columns were removed to simplify the dataset.

# %%
df.head(5)
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    release_year rating                                          listed_in  \
# 0          2020  PG-13                                      Documentaries
# 1          2021  TV-MA    International TV Shows, TV Dramas, TV Mysteries
# ...

# %%
df['director'] = df['director'].fillna('Unknown Director')
df['cast'] = df['cast'].fillna('Unknown Cast')
df['country'] = df['country'].fillna('Unknown Country')
df['rating'] = df['rating'].fillna('Unknown')

# %% [markdown]
# Missing values were filled with "Unknown" labels to avoid data loss during analysis.

# %%
df.head(5)
# Out:
#       type                  title          director  \
# 0    Movie   Dick Johnson Is Dead   Kirsten Johnson
# 1  TV Show          Blood & Water  Unknown Director
# 2  TV Show              Ganglands   Julien Leclercq
# 3  TV Show  Jailbirds New Orleans  Unknown Director
# 4  TV Show           Kota Factory  Unknown Director
#
#                                                 cast          country  \
# 0                                       Unknown Cast    United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...     South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  Unknown Country
# 3                                       Unknown Cast  Unknown Country
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...            India
#
#    release_year rating                                          listed_in  \
# 0          2020  PG-13                                      Documentaries
# 1          2021  TV-MA    International TV Shows, TV Dramas, TV Mysteries
# ...

# %%
df.to_csv(
    r"C:\Users\DELL\Desktop\PROJECTS\Netflix-Movie-Recommendation\data\clean data\netflix_titles_clean.csv",
    index=False
)
